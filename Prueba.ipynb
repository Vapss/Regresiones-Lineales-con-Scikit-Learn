# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 


#Lee el corpus original del archivo de entrada y lo pasa a una DataFrame
df = pd.read_csv('cal_housing.csv', sep=',', engine='python')

sns.pairplot(df, x_vars=['median_income', 'median_house_value'], y_vars='median_house_value', size=5)

X = df[i].values
y = df['price'].values
plt.scatter(X,y)
plt.xlabel('num_bedrooms')
plt.ylabel('price')

#~ plt.show()

#~ #Correlación 
#~ X = df.drop(['price'],axis=1).values
#~ print (X)

correlation_matrix = df.corr().round(2)
print(correlation_matrix)
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()
# Out:
# /Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'median_house_value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Untitled-1.ipynb Cell 1' in <module>
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=5'>6</a> #Lee el corpus original del archivo de entrada y lo pasa a una DataFrame
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=6'>7</a> df = pd.read_csv('cal_housing.csv', sep=',', engine='python')
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=8'>9</a> sns.pairplot(df, x_vars=['median_income', 'median_house_value'], y_vars='median_house_value', size=5)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=10'>11</a> X = df[i].values
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000000untitled?line=11'>12</a> y = df['price'].values
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=35'>36</a>     warnings.warn(
#      <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=36'>37</a>         "Pass the following variable{} as {}keyword arg{}: {}. "
#      <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=37'>38</a>         "From version 0.12, the only valid positional argument "
#    (...)
#      <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=42'>43</a>         FutureWarning
#      <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=43'>44</a>     )
#      <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=44'>45</a> kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/_decorators.py?line=45'>46</a> return f(**kwargs)
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py:2126, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=2123'>2124</a> diag_kws.setdefault("legend", False)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=2124'>2125</a> if diag_kind == "hist":
# -> <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=2125'>2126</a>     grid.map_diag(histplot, **diag_kws)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=2126'>2127</a> elif diag_kind == "kde":
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=2127'>2128</a>     diag_kws.setdefault("fill", True)
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py:1461, in PairGrid.map_diag(self, func, **kwargs)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=1457'>1458</a> else:
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=1458'>1459</a>     plt.sca(ax)
# -> <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=1460'>1461</a> vector = self.data[var]
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=1461'>1462</a> if self._hue_var is not None:
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/seaborn/axisgrid.py?line=1462'>1463</a>     hue = self.data[self._hue_var]
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///Users/vaps/opt/anaconda3/envs/ia/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'median_house_value'
